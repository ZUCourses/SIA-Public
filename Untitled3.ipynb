# %%
import pandas as pd
df1 = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/main/BuildingsTallest.csv")
df1
# Out:
#           Country           City  Rank                         Building  \
# 0           China       Shanghai     2                   Shanghai_Tower
# 1           China       Shenzhen     4           Ping_An_Finance_Centre
# 2           China      Guangzhou     7               CTF_Finance_Centre
# 3           China       Shanghai     9  Shanghai_World_Financial_Center
# 4           China      Hong_Kong    10    International_Commerce_Centre
# ..            ...            ...   ...                              ...
# 59  United_States  New_York_City    38            Bank_of_America_Tower
# 60  United_States        Chicago    49                       Aon_Center
# 61  United_States        Chicago    51              John_Hancock_Center
# 62  United_States    Los_Angeles    59            Wilshire_Grand_Center
# 63        Vietnam          Hanoi    46    Keangnam_Hanoi_Landmark_Tower
#
#     Height  Floors  Year_Built
# 0      632     128        2015
# 1      600     115        2016
# 2      530     111        2016
# 3      492     101        2008
# 4      484     118        2010
# ..     ...     ...         ...
# 59     366      54        2009
# 60     346      83        1973
# 61     344     100        1969
# 62     335      73        2016
# 63     350      72        2011
#
# [64 rows x 7 columns]

# %%
df2=df1.query("Country=='UAE' & Height>400" )
df2
# Out:
#    Country   City  Rank        Building  Height  Floors  Year_Built
# 39     UAE  Dubai     1    Burj_Khalifa     828     163        2010
# 40     UAE  Dubai    18      Marina_101     427     101        2015
# 41     UAE  Dubai    22  Princess_Tower     414     101        2012

# %%
import pandas as pd
df1 = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/main/Mammals.csv")
df1
# Out:
#                  Mammal           Order  LifeSpan  Height     Mass  Sleep  \
# 0       AfricanElephant     Proboscidae        70     4.0  6400.00      3
# 1         AsianElephant     Proboscidae        70     3.0  5000.00      4
# 2           BigBrownBat      Chiroptera        19     0.1     0.02     20
# 3     BottlenoseDolphin         Cetacea        25     3.5   635.00      5
# 4               Cheetah       Carnivora        14     1.5    50.00     12
# 5           DomesticCat       Carnivora        16     0.8     4.50     12
# 6                Donkey  Perissodactyla        40     1.2   187.00      3
# 7               Giraffe    Artiodactyla        25     5.0  1100.00      2
# 8              GrayWolf       Carnivora        16     1.6    80.00     13
# 9              GreySeal      Pinnipedia        30     2.1   275.00      6
# 10       GroundSquirrel        Rodentia         9     0.3     0.10     15
# 11                Horse  Perissodactyla        25     1.5   521.00      3
# 12           HouseMouse        Rodentia         3     0.1     0.03     12
# 13                Human         Primate        80     1.9    80.00      8
# 14               Jaguar       Carnivora        20     1.8   115.00     11
# 15                 Lion       Carnivora        15     2.5   250.00     20
# 16  NineBandedArmadillo       Xenarthra        10     0.6     7.00     17
# 17                  Pig    Artiodactyla        10     1.0   192.00      8
# 18               Rabbit      Lagomorpha         5     0.5     3.00     11
# 19               RedFox       Carnivora         7     0.8     5.00     10
# 20         SpottedHyena       Carnivora        25     0.9    70.00     18
#
#     Speed Habitat    Diet
# 0      40    land  plants
# 1      40    land  plants
# 2      40    land    meat
# 3      37   water    meat
# 4     110    land    meat
# 5      50    land    meat
# 6      50    land  plants
# 7      50    land  plants
# 8      64    land    meat
# 9      19    both    meat
# 10     19    land    both
# 11     69    land  plants
# 12     13    land    both
# 13     45    land    both
# 14     60    land    meat
# 15     80    land    meat
# 16      1    land    meat
# 17     18    land    both
# 18     56    land  plants
# 19     48    land    both
# 20     64    land    meat

# %%
import pandas as pd
df1 = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/main/Mammals.csv")
df1
# Out:
#                  Mammal           Order  LifeSpan  Height     Mass  Sleep  \
# 0       AfricanElephant     Proboscidae        70     4.0  6400.00      3
# 1         AsianElephant     Proboscidae        70     3.0  5000.00      4
# 2           BigBrownBat      Chiroptera        19     0.1     0.02     20
# 3     BottlenoseDolphin         Cetacea        25     3.5   635.00      5
# 4               Cheetah       Carnivora        14     1.5    50.00     12
# 5           DomesticCat       Carnivora        16     0.8     4.50     12
# 6                Donkey  Perissodactyla        40     1.2   187.00      3
# 7               Giraffe    Artiodactyla        25     5.0  1100.00      2
# 8              GrayWolf       Carnivora        16     1.6    80.00     13
# 9              GreySeal      Pinnipedia        30     2.1   275.00      6
# 10       GroundSquirrel        Rodentia         9     0.3     0.10     15
# 11                Horse  Perissodactyla        25     1.5   521.00      3
# 12           HouseMouse        Rodentia         3     0.1     0.03     12
# 13                Human         Primate        80     1.9    80.00      8
# 14               Jaguar       Carnivora        20     1.8   115.00     11
# 15                 Lion       Carnivora        15     2.5   250.00     20
# 16  NineBandedArmadillo       Xenarthra        10     0.6     7.00     17
# 17                  Pig    Artiodactyla        10     1.0   192.00      8
# 18               Rabbit      Lagomorpha         5     0.5     3.00     11
# 19               RedFox       Carnivora         7     0.8     5.00     10
# 20         SpottedHyena       Carnivora        25     0.9    70.00     18
#
#     Speed Habitat    Diet
# 0      40    land  plants
# 1      40    land  plants
# 2      40    land    meat
# 3      37   water    meat
# 4     110    land    meat
# 5      50    land    meat
# 6      50    land  plants
# 7      50    land  plants
# 8      64    land    meat
# 9      19    both    meat
# 10     19    land    both
# 11     69    land  plants
# 12     13    land    both
# 13     45    land    both
# 14     60    land    meat
# 15     80    land    meat
# 16      1    land    meat
# 17     18    land    both
# 18     56    land  plants
# 19     48    land    both
# 20     64    land    meat

# %%
df1['Mass'].min()
# Out:
# 0.02

# %%
df1['Mass'].max()
# Out:
# 6400.0

# %%
df1['Mass'].mean(axis="rows")
# Out:
# 713.0785714285715

# %%
df1.query('Habitat=='Land'')
# Out:
#   File "<ipython-input-16-64b276405096>", line 1
#     df1.query('Habitat=='Land'')
#                          ^
# SyntaxError: invalid syntax

# %%
df_plants=df1.query("Diet=='plants'" )
df_plants
df_plants['Mass'].mean(axis="rows")
# Out:
# 2201.8333333333335

# %%
df_meat=df1.query("Diet=='meat'" )
df_meat
df_meat['Mass'].mean(axis="rows")
# Out:
# 148.652

# %%
df_plants=df1.query("Diet=='plants'" )
df_plants['Mass'].mean(axis="rows")
df_meat=df1.query("Diet=='meat'" )
df_meat['Mass'].mean(axis="rows")
# Out:
# 148.652

# %%
df_pie=df1['Habitat'].value_counts()
df_pie
# Out:
# land     19
# both      1
# water     1
# Name: Habitat, dtype: int64

# %%
df1['Diet'].value_counts(normalize=True)
# Out:
# meat      0.476190
# plants    0.285714
# both      0.238095
# Name: Diet, dtype: float64

# %%
import pandas as pd
dfc = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/main/Cats.csv")
dfc
# Out:
#        Sex            Name  Age  Weight  BodyLength  TailLength EyeColor  \
# 0     male  Tomodachi_Joto    1       7          14         1.5   yellow
# 1     male         Oddfuzz    5      18          21         9.0   yellow
# 2     male          Pepper    2      12          17         9.0   yellow
# 3     male       Alexander   18      11          21        11.0    green
# 4     male           Weary    8      15          17        12.0    green
# 5     male            K.C.    5      16          24        12.0   yellow
# 6     male        Charcoal   11      12          21        13.0   yellow
# 7     male          George   12      15          21        13.0    green
# 8     male         Harmony    3      12          24        11.0   yellow
# 9   female      Gray_Kitty    3       9          15         9.0    green
# 10  female      Strawberry   16      15          21        10.0    green
# 11  female          Tigger    4       8          17        10.0   yellow
# 12  female  Lady_Jane_Grey    4       9          19        11.0   yellow
# 13  female         Melissa    8      11          21        11.0   yellow
# 14  female         Mittens   14      11          17        11.0   yellow
# 15  female         Peebles    5       9          17        11.0    green
# 16  female            Diva    4      11          20        12.0    green
# 17  female            Lady   10       9          17        13.0   yellow
# 18  female    Peau_de_Soie   15       7          16        13.0    green
# 19  female       Cleopatra    4       7          18         9.0   yellow
#
#    PadColor
# 0      pink
# 1      pink
# 2      pink
# 3     black
# 4      pink
# 5     black
# 6     black
# 7     black
# 8     black
# 9      gray
# 10    black
# 11    brown
# 12     gray
# 13     pink
# 14     pink
# 15    black
# 16     pink
# 17    black
# 18     pink
# 19     pink

# %%
dfc['Age'].plot(kind="hist")
dfc.plot.scatter(x='Weight', y='BodyLength')
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='BodyLength'>

# %%
dfc1=dfc.query("Sex=='male'")
dfc1
dfc1['PadColor'].value_counts(normalize=True)
# Out:
# black    0.555556
# pink     0.444444
# Name: PadColor, dtype: float64

# %%
dfc2=dfc.query("Sex=='female'")
dfc2
dfc2['PadColor'].value_counts(normalize=True)
# Out:
# pink     0.454545
# black    0.272727
# gray     0.181818
# brown    0.090909
# Name: PadColor, dtype: float64

# %%
dfc['Sex'].value_counts()
# Out:
# female    11
# male       9
# Name: Sex, dtype: int64

# %%
import pandas as pd
dfc = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/main/Cats.csv")
dfc['Sex'].value_counts()
# Out:
# female    11
# male       9
# Name: Sex, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie (df_pie)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fec90266160>,
#   <matplotlib.patches.Wedge at 0x7fec90266eb0>,
#   <matplotlib.patches.Wedge at 0x7fec90279100>],
#  [Text(-1.0511300921469773, 0.3242306731064897, ''),
#   Text(0.9910657730456088, -0.4772720749190236, ''),
#   Text(1.087713916065691, -0.16394644490515556, '')])

# %%
import matplotlib.pyplot as plt
plt.bar (df_pie, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-54fa9f1d94fc> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.bar (df_pie)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
df_pie.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Habitat'>

# %%
df_pie.plot(kind='bar')
plt.xlabel('Number of pets')
# Out:
# Text(0.5, 0, 'Number of pets')

# %%
import pandas as pd
df1 = pd.read_csv("https://raw.githubusercontent.com/ZUCourses/SIA-Public/main/Mammals.csv")
df1
# Out:
#                  Mammal           Order  LifeSpan  Height     Mass  Sleep  \
# 0       AfricanElephant     Proboscidae        70     4.0  6400.00      3
# 1         AsianElephant     Proboscidae        70     3.0  5000.00      4
# 2           BigBrownBat      Chiroptera        19     0.1     0.02     20
# 3     BottlenoseDolphin         Cetacea        25     3.5   635.00      5
# 4               Cheetah       Carnivora        14     1.5    50.00     12
# 5           DomesticCat       Carnivora        16     0.8     4.50     12
# 6                Donkey  Perissodactyla        40     1.2   187.00      3
# 7               Giraffe    Artiodactyla        25     5.0  1100.00      2
# 8              GrayWolf       Carnivora        16     1.6    80.00     13
# 9              GreySeal      Pinnipedia        30     2.1   275.00      6
# 10       GroundSquirrel        Rodentia         9     0.3     0.10     15
# 11                Horse  Perissodactyla        25     1.5   521.00      3
# 12           HouseMouse        Rodentia         3     0.1     0.03     12
# 13                Human         Primate        80     1.9    80.00      8
# 14               Jaguar       Carnivora        20     1.8   115.00     11
# 15                 Lion       Carnivora        15     2.5   250.00     20
# 16  NineBandedArmadillo       Xenarthra        10     0.6     7.00     17
# 17                  Pig    Artiodactyla        10     1.0   192.00      8
# 18               Rabbit      Lagomorpha         5     0.5     3.00     11
# 19               RedFox       Carnivora         7     0.8     5.00     10
# 20         SpottedHyena       Carnivora        25     0.9    70.00     18
#
#     Speed Habitat    Diet
# 0      40    land  plants
# 1      40    land  plants
# 2      40    land    meat
# 3      37   water    meat
# 4     110    land    meat
# 5      50    land    meat
# 6      50    land  plants
# 7      50    land  plants
# 8      64    land    meat
# 9      19    both    meat
# 10     19    land    both
# 11     69    land  plants
# 12     13    land    both
# 13     45    land    both
# 14     60    land    meat
# 15     80    land    meat
# 16      1    land    meat
# 17     18    land    both
# 18     56    land  plants
# 19     48    land    both
# 20     64    land    meat
