# %% [markdown]
# **ICS214 Assignment 4 Final Problem Set**

# %% [markdown]
# **Problem 1. Extreme Temperatures (#Probability,
# #ModelSelection)**
# ![Screen%20Shot%202023-04-23%20at%2012.17.19%20PM.png](attachment:Screen%20Shot%202023-04-23%20at%2012.17.19%20PM.png)

# %% [markdown]
# 1.1. ![Screen%20Shot%202023-04-23%20at%2012.21.11%20PM.png](attachment:Screen%20Shot%202023-04-23%20at%2012.21.11%20PM.png)

# %%
#cell for problem 1.1

# %% [markdown]
# 1.2. ![Screen%20Shot%202023-04-23%20at%2012.20.21%20PM.png](attachment:Screen%20Shot%202023-04-23%20at%2012.20.21%20PM.png)

# %%
#cell for problem 1.2

# %% [markdown]
# 1.3.![Screen%20Shot%202023-04-23%20at%2012.25.16%20PM.png](attachment:Screen%20Shot%202023-04-23%20at%2012.25.16%20PM.png)

# %%
#cell for problem 1.3

# %% [markdown]
# 1.4. ![Screen%20Shot%202023-04-23%20at%2012.23.33%20PM.png](attachment:Screen%20Shot%202023-04-23%20at%2012.23.33%20PM.png)

# %% [markdown]
# #cell for problem 1.4

# %% [markdown]
# **Problem 2. Starry Night (#ParameterEstimation)**
#
# ![final-problems-ics214-version-%20%281%29.jpg](attachment:final-problems-ics214-version-%20%281%29.jpg)

# %%
#cell for problem 2

# %%
#extra cell for problem 2

# %% [markdown]
# #cell for problem 2
